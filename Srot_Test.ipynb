# %% [markdown]
# <a href="https://colab.research.google.com/github/amartinez-se/03MIAR---Algoritmos-de-Optimizacion-2025/blob/main/Srot_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Primer algoritmo

# %%
import sorting
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2766944646.py in <cell line: 0>()
# ----> 1 import sorting
#
# ModuleNotFoundError: No module named 'sorting'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install sorting
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sorting: filename=sorting-1.0.3-py3-none-any.whl size=5859 sha256=7a9c656998c6e63f15ede1d78c69076112eec846135729cdc129e52c90f675ea
#   Stored in directory: /root/.cache/pip/wheels/1e/4f/b2/859fb60c464ab3d3d9526a5ec0f3d3166f5b9a1c719dee88ad
# Successfully built sorting
# ...

# %%
import sorting
lista = [4,5,32,2,53,67,23]
lista_ordenada = sorting.bubble(lista)
print(lista_ordenada)
# Out:
# [2, 4, 5, 23, 32, 53, 67]
